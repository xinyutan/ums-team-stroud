# %%
import pandas as pd
from googleapiclient.discovery import build


# Build custom search API service

devKey = "" # fill in
cse_id = "000991425950231841099:8_ifpeoag3s"        # custom search engine id

service = build("customsearch", "v1", developerKey=devKey)

# %%
# Get a list of search terms

trans_df = pd.read_csv('./ums_viz.csv')
perfs = trans_df['perf_name'].value_counts().index

print "number of unique performance names:", len(perfs)

for p in perfs:
    print "\t"+p
# Out:
# number of unique performance names: 144
# 	Handel's Messiah
# 	San Francisco Sympho
# 	New York Philharmoni
# 	Chicago Symphony Orc
# 	Ballet Preljocaj
# 	Audra McDonald
# 	Einstein on the Beac
# 	Jazz at Lincoln Cent
# 	Apollo's Fire
# 	Joshua Bell
# 	Mariinsky Orchestra
# 	Detroit Symphony Orc
# 	The Silk Road Ensemb
# 	London Philharmonic
# 	The Infernal Comedy
# 	Andras Schiff, piano
# 	Martha Graham Dance
# 	Murray Perahia
# 	Complicite
# 	Alison Balsom
# 	Gilberto Gil
# 	Cloud Gate Dance The
# 	Joshua Bell, violin
# 	Anne-Sophie Mutter,
# 	Propeller: Twelfth N
# 	JLCO with Wynton
# 	Kodo
# 	Hubbard Street Dance
# 	Gate Theatre
# 	Milhaud's Oresteian
# 	Hamburg Symphony
# 	A Night in Treme
# 	Bobby McFerrin
# 	Zakir Hussain
# 	Propeller: Taming of
# 	Yuja Wang, piano
# 	Takacs Quartet
# 	Denis Matsuev, piano
# 	Mark Morris Dance Gr
# 	Hagen Quartet
# 	Kidd Pivot
# 	Rhinoceros
# 	Canadian Brass
# 	Aspen Santa Fe Balle
# 	St Petersburg Philha
# 	Handel's Radamisto
# 	From Cass Corridor
# 	Esperanza Spalding
# 	Ukulele Orchestra of
# 	Sweet Honey In The R
# 	Olga Kern, piano
# 	Israel Philharmonic
# 	Goran Bregovic
# 	Mariachi Vargas de T
# 	Manganiyar Seduction
# 	Random Dance
# 	Ahmad Jamal
# 	The Andersen Project
# 	James Blake
# 	Amjad Ali Khan
# 	Max Raabe
# 	Dianne Reeves Quarte
# 	SITI: Trojan Women
# 	Akademie fur Alte Mu
# 	Brooklyn Rider
# 	Angelique Kidjo
# 	Emerson String Quart
# 	Berlin Philharmonic
# 	Belcea Quartet
# 	NT - Macbeth
# 	The King's Singers
# 	Chris Thile
# 	Kremerata Baltica
# 	Kronos Quartet
# 	Ragamala Dance
# 	Sabine Meyer
# 	Dave Holland
# 	RSC in HD - Richard
# 	Blind Summit
# 	New Century Chamber
# 	Chanticleer
# 	1927: The Animals an
# 	Charles Lloyd Quarte
# 	Chamber Ens of the S
# 	Jerusalem String Qua
# 	Les Violons du Roy
# 	Diego El Cigala
# 	Artemis Quartet
# 	Prudencia Hart
# 	Suzhou Kun Troupe
# 	The Tallis Scholars
# 	Bullet Catch
# 	Tara Erraught, mezzo
# 	Compagnie Kafig
# 	NT - The Audience
# 	Hamid Al-Saadi
# 	Pavel Haas Quartet
# 	State Symphony Capel
# 	Dan Zanes and Friend
# 	St Lawrence Quartet
# 	Brahms's Requiem
# 	Cheikh Lo
# 	One Night in Bamako
# 	Stile Antico
# 	Jason Moran's Fats W
# 	Ariel Quartet
# 	Alfredo Rodriguez &
# 	Beijing Guitar Duo
# 	Elias String Quartet
# 	AnDa Union
# 	Los Angeles Guitar Q
# 	Ensemble Basiani
# 	Theatre des Bouffes
# 	NT - Frankenstein
# 	NT - Othello
# 	St Lawrence String Q
# 	Schola Cantorum of V
# 	Steve Lehman Octet
# 	Breakin' Curfew
# 	Fela!
# 	Fred Hersch Trio
# 	Gabriel Kahane
# 	FAM -Aspen Santa Fe
# 	NT - Coriolanus
# 	Asif Ali Khan
# 	NT - The Comedy of E
# 	NT - The Curious Inc
# 	Colin Stetson
# 	NT - The Kitchen
# 	NT - She Stoops
# 	NT - One Man, Two Gu
# 	NT - Collaborators
# 	NT - The Magistrate
# 	NT - Timon of Athens
# 	NT - People
# 	NT - Traveling Ligh
# 	NT - Last of the Hau
# 	NT - This House
# 	Mavericks All Access
# 	DC: Ballet Preljocaj
# 	NT - War Horse
# 	Diego - post perf
# 	DC: Hubbard
# 	Usher party

# %%
# Perform a custom search for each query
# This search only looks at the UMS website

results = {}
for p in perfs:
    print p + "...",
    results[p] = service.cse().list(q=p, cx=cse_id).execute()
    print "complete."
# Out:
# Handel's Messiah... complete.
# San Francisco Sympho... complete.
# New York Philharmoni... complete.
# Chicago Symphony Orc... complete.
# Ballet Preljocaj... complete.
# Audra McDonald... complete.
# Einstein on the Beac... complete.
# Jazz at Lincoln Cent... complete.
# Apollo's Fire... complete.
# Joshua Bell... complete.
# Mariinsky Orchestra... complete.
# Detroit Symphony Orc... complete.
# The Silk Road Ensemb... complete.
# London Philharmonic... complete.
# The Infernal Comedy... complete.
# Andras Schiff, piano... complete.
# Martha Graham Dance... complete.
# Murray Perahia... complete.
# Complicite... complete.
# Alison Balsom... complete.
# Gilberto Gil... complete.
# Cloud Gate Dance The... complete.
# Joshua Bell, violin... complete.
# Anne-Sophie Mutter,... complete.
# Propeller: Twelfth N... complete.
# JLCO with Wynton... complete.
# Kodo... complete.
# Hubbard Street Dance... complete.
# Gate Theatre... complete.
# Milhaud's Oresteian... complete.
# Hamburg Symphony... complete.
# A Night in Treme... complete.
# Bobby McFerrin... complete.
# Zakir Hussain... complete.
# Propeller: Taming of... complete.
# Yuja Wang, piano... complete.
# Takacs Quartet... complete.
# Denis Matsuev, piano... complete.
# Mark Morris Dance Gr... complete.
# Hagen Quartet... complete.
# Kidd Pivot... complete.
# Rhinoceros... complete.
# Canadian Brass... complete.
# Aspen Santa Fe Balle... complete.
# St Petersburg Philha... complete.
# Handel's Radamisto... complete.
# From Cass Corridor... complete.
# Esperanza Spalding... complete.
# Ukulele Orchestra of... complete.
# Sweet Honey In The R... complete.
# Olga Kern, piano... complete.
# Israel Philharmonic... complete.
# Goran Bregovic... complete.
# Mariachi Vargas de T... complete.
# Manganiyar Seduction... complete.
# Random Dance... complete.
# Ahmad Jamal... complete.
# The Andersen Project... complete.
# James Blake... complete.
# Amjad Ali Khan... complete.
# Max Raabe... complete.
# Dianne Reeves Quarte... complete.
# SITI: Trojan Women... complete.
# Akademie fur Alte Mu... complete.
# Brooklyn Rider... complete.
# Angelique Kidjo... complete.
# Emerson String Quart... complete.
# Berlin Philharmonic... complete.
# Belcea Quartet... complete.
# NT - Macbeth... complete.
# The King's Singers... complete.
# Chris Thile... complete.
# Kremerata Baltica... complete.
# Kronos Quartet... complete.
# Ragamala Dance... complete.
# Sabine Meyer... complete.
# Dave Holland... complete.
# RSC in HD - Richard... complete.
# Blind Summit... complete.
# New Century Chamber... complete.
# Chanticleer... complete.
# 1927: The Animals an... complete.
# Charles Lloyd Quarte... complete.
# Chamber Ens of the S... complete.
# Jerusalem String Qua... complete.
# Les Violons du Roy... complete.
# Diego El Cigala... complete.
# Artemis Quartet... complete.
# Prudencia Hart... complete.
# Suzhou Kun Troupe... complete.
# The Tallis Scholars... complete.
# Bullet Catch... complete.
# Tara Erraught, mezzo... complete.
# Compagnie Kafig... complete.
# NT - The Audience... complete.
# Hamid Al-Saadi... complete.
# Pavel Haas Quartet... complete.
# State Symphony Capel... complete.
# Dan Zanes and Friend... complete.
# St Lawrence Quartet... complete.
# Brahms's Requiem... complete.
# Cheikh Lo...
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-5-d8d12693dac7> in <module>()
#       5 for p in perfs:
#       6     print p + "...",
# ----> 7     results[p] = service.cse().list(q=p, cx=cse_id).execute()
#       8     print "complete."
#       9
#
# /Users/stroud/Tools/anaconda2/lib/python2.7/site-packages/oauth2client/util.pyc in positional_wrapper(*args, **kwargs)
#     133                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     134                     logger.warning(message)
# --> 135             return wrapped(*args, **kwargs)
#     136         return positional_wrapper
#     137
#
# /Users/stroud/Tools/anaconda2/lib/python2.7/site-packages/googleapiclient/http.pyc in execute(self, http, num_retries)
#     758       callback(resp)
#     759     if resp.status >= 300:
# --> 760       raise HttpError(resp, content, uri=self.uri)
#     761     return self.postproc(resp, content)
#     762
#
# HttpError: <HttpError 403 when requesting https://www.googleapis.com/customsearch/v1?q=Cheikh+Lo&alt=json&cx=000991425950231841099%3A8_ifpeoag3s&key=AIzaSyB7b43BMgGh2EnepXY_DrZimYFbdqku1Lw returned "Daily Limit Exceeded. The quota will be reset at midnight Pacific Time (PT). You may monitor your quota usage and adjust limits in the API Console: https://console.developers.google.com/apis/api/customsearch/quotas?project=699166398247">

# %%
# Well we hit a quota (100/day). No worries, we already got most of the results.
# Let's save them to be safe

import pickle

print "Successfully searched:", len(results.keys())
print "Saving search results...",

with open('./search_results_4_20.pkl', 'w') as f:
    pickle.dump(results, f)
    print "success"
# Out:
#  Successfully searched: 101
# Saving search results... success

# %%
# What do the search results look like?

print results["Handel's Messiah"].keys()                 # All of the search information retrieved for this query
print len(results["Handel's Messiah"]['items'])          # Number of search items returned
print results["Handel's Messiah"]['items'][0].keys()     # Data returned for a single retrieved search item

f = open('searched_urls.txt', 'w')

for p in perfs:
    if p in results.keys():
        f.write(p+'\n')
        if 'items' in results[p].keys():
            for item in results[p]['items']:
                f.write("\t"+item['link']+'\n')
        else:
            f.write("\tNone found\n")
            
f.close()
# Out:
# [u'kind', u'url', u'items', u'context', u'queries', u'searchInformation']
# 10
# [u'kind', u'title', u'displayLink', u'htmlTitle', u'formattedUrl', u'htmlFormattedUrl', u'pagemap', u'snippet', u'htmlSnippet', u'link', u'cacheId']
